# %%
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO

figwidth = 8

# %% [markdown]
# *kritik*
# 1. Keine Coworking
# 2. Keine latex auto completion serhr schade
# 3. kein auto inhaltverzeichnis(gibt es anscheinend in der cloud)
# 4. keine automatisch equation Nummerierung
#
# # V2 - Interferenz und Wellenlängenmessung
#
# **Durchführende Praktikanten:**  Max Mustermann, Anna Musterfrau
# **Betreuender Assistent:**  Merlin Musterassistent
# **Protokoll-Erstabgabe:** XX.XX.XXXX
#
# **Ergebnisse des Versuchs im Vergleich mit Literatur werten:**
# $$
#     \begin{align*}
#         \lambda_{berechnet} &= 5,269 \cdot 10^{-7} \pm 1,436 \cdot 10^{-9} m\\
#         \lambda_{grafisch} &= 5,269 \cdot 10^{-7} \pm 1,745 \cdot 10^{-9} m\\
#         d_{berechnet} &= 8,730 \cdot 10^{-5} \pm 2,496 \cdot 10^{-6} m\\
#         d_{grafisch} &= 8,783 \cdot 10^{-5} \pm 1,745 \cdot 10^{-9} m
#     \end{align*}
# $$

# %% [markdown]
# ## 1 Theoretische Grundlagen
# ### 1.1 Wellen
#
# Wellen sind periodische Störungen in Raum und Zeit. Sie breiten sich allgemein
# dreidimensional im Raum aus. Wenn ein Stein  in einen Teich  geworfen wird, entstehen
# konzentrische Kreise, die mit der Zeit immer weiter von der Eintauchstelle weglaufen.
# Würde man den Querschnitt der Wasseroberfläche fotografieren, bilden die
# unterschiedlichen Wasserhöhen ein räumliches periodisches Muster zu einer festen Zeit.
# Den Abstand zwischen zwei benachbarten Maxima nennt man **Wellenlänge** $\lambda$.
# Andererseits könnte man die Wasserhöhe an genau einem festen Punkt filmen und dabei
# sehen, wie die Wassergrenzfläche an diesem Punkt sich periodisch in der Zeit auf und ab
# bewegt. Die Zeit zwischen zwei aufeinanderfolgenden Maxima nennt man die Periodendauer T.
# Das reziproke der Periodendauer gibt an, wie oft pro Sekunde eine vollständige zeitliche Periode durchlaufen wird und wird **Frequenz** $\nu = 1/T$ genannt.
#
# Mathematisch wird eine Welle allgemein durch folgende Funktion beschrieben:
# $$
#     y_1 = A \cdot \sin (\vec{k} \cdot \vec{r} - \omega t) \tag{1.1}
# $$
#
# Dabei bezeichnet $y_1$ den Bertrag der Wellenfunktion am Ort $\vec{r}$ zur Zeit t,
# A die (maximale) Amplitude der Welle, $\vec{k}$ den Wellenvektor und $\omega$ die Kreisfrequenz. Der Wellenvektor gibt
# die Ausbreitungsrichtung der Welle an. Dessen Betrag (genannt „Wellenzahl“) k ist folgendermaßen mit der Wellenlänge $\lambda$ verknüpft
# $$
#     k = \frac{2\pi}{\lambda} \tag{1.2}
# $$
# Diese Zahl gibt an, um wieviel der räumliche Phasenwinkel pro Längeneinheit
# voranschreitet (in der Einheit "rad": $360\degree$ entsprechen $2\pi$ im Bogenmaß (rad)).
# Die Kreisfrequenz
# $$
#     \omega = \frac{2\pi}{T} = 2\pi \nu \tag{1.3}
# $$
# gibt an, wie weit der zeitliche Phasenwinkel (in rad) pro Zeiteinheit voranschreitet.
#
# Häufig reicht für die prinzipielle Beschreibung von Wellenphänomenen auch eine
# räumlich eindimensionale Darstellung:
# $$
#     y_1 = A \cdot \sin (kx - \omega t) \tag{1.4}
# $$
# Mit  dieser  Gleichung kann auch eine elektromagnetische Welle („Licht“) beschrieben
# werden: Dann ist A der Betrag oder die Amplitude des elektrischen Feldstärkevektors
# (der steht i.A. immer senkrecht zur Ausbreitungsrichtung, die magnetische Komponente
# wird hier nicht weiter berücksichtigt).
#
# Abbildung 2.1 zeigt eine Momentaufnahme einer solchen Sinuswelle im Raum. Es ist die
# momentane  Auslenkung y  in  Abhängigkeit  vom  Ort x  aufgetragen.  Die  Wellenberge
# bewegen sich mit der Phasengeschwindigkeit $\vec{v_p}$ durch den Raum. Für Licht im Vakuum
# hat die Phasengeschwindigkeit den Wert der Lichtgeschwindigkeit $c_0$ܿ
#
# <div style="text-align:center;">
#     <img src="Lichtwelle.png" width=600>
#     <p><b>Abbildung 2.1:</b> Darstellung einer sinusförmigen Lichtwelle zu zwei verschiedenen Zeiten.  </p>
# </div>

# %% [markdown]
# ### 1.2 Interferenz
# Das Überlagern von zwei oder mehr Wellenamplituden nennt man Interferenz. Trifft ein
# Wellenmaximum einer Welle auf ein Wellenminimum einer anderen, kommt es zu einer
# Auslöschung  der  Störung  (wenn  beide  Amplituden  gleich  groß  sind);  dieses  Phänomen
# heißt  „destruktive  Interferenz“.  Treffen  sich  dagegen  zwei  Maxima,  kommt  es  zu  einer
# Verstärkung der Störung und wird „konstruktive Interferenz“ genannt.
#
#
# <div style="text-align:center;">
#     <img src="ueberlagerung_wellen.png" width=600>
#     <p><b>Abbildung 2.2:</b> Überlagerung zweier Sinus-Wellen mit Gangunterschied </p>
# </div>
#
#
# Mathematisch wird das einfach durch Addition von (zwei) Sinus-Funktionen beschrieben (siehe Abbildung 2.2); Eine der beiden Wellen hat gegenüber der anderen einen Gangunterschied $\delta$.
# $$
#     \begin{align*}
#         y_1 &= A \cdot \sin (kx) \\ \tag{1.5}
#         y_2 &= A \cdot \sin (k(x + \delta ))
#     \end{align*}
# $$
# Für  die  Überlagerung  von  Lichtwellen  spielt  die  Zeitabhängigkeit  in  erster  Linie  keine
# Rolle und wurde daher weggelassen.
#
# Die Überlagerung der beiden Wellen ergibt
# $$
#     y = y_1 + y_2 = A \cdot (\sin (kx) + \sin(l(x + \delta ))) \tag{1.7}
# $$
# Die Summe auf der rechten Seite kann maximal werden, wenn z.B. $\delta = 0$ ist. Wegen der
# Periodizität ist die konstruktive Interferenz auch möglich, wenn der Gangunterschied ein
# **ganzzahliges Vielfaches der Wellenlänge** ist, insgesamt also:
# $$
#     \delta = n \cdot \lambda \quad n = 0,1,2,... \tag{1.8}
# $$
# Destruktive  Interferenz  tritt  auf,  wenn  die  Summe  auf  der  rechten  Seite  0  wird.  Das
# geschieht, wenn der Gangunterschied in **ungeradzahliges Vielfaches der halben
# Wellenlänge** ist:
# $$
#     \delta = (2n +1) \cdot \frac{\lambda}{2} \quad n=0,1,2,.. \tag{1.8}
# $$
#
# <div style="text-align:center;">
#     <div style="display: inline-block; margin: 10px;">
#         <img src="KonstruktiveInterferenz.png" width=300> <br>
#         <p><b>Abbildung 2.3:</b> Konstruktive Interferenz </p>
#     </div>
#     <div style="display: inline-block; margib: 10px;">
#         <img src="DestruktiveInterferenz.png" width=300> <br>
#         <p><b>Abbildung 2.4:</b> Destruktive Interferenz
#     </div>
# </div>

# %% [markdown]
# ### 1.3 Beugung
# Unter  Beugung  versteht  man  die  Ablenkung  von  Wellen,  die  durch  Interferenz  der
# Teilwellenuntereinander  entsteht.  Beugung  beobachtet  man,  wenn  eine  Welle  auf  ein
# Hindernis  trifft,  zum  Beispiel  einen  Spalt,  ein  Gitter,  eine  Lochblende  oder  ähnliches.  Je
# nach Beschaffenheit des Hindernisses entsteht dabei ein charakteristisches
# Beugungsmuster. Beugung wird durch das Huygens‘sche Prinzip erklärt: jeder Punkt des
# Hindernisses wird Ausgangspunkt von neuen Kugelwellen. Dadurch kommt es zu
# Überlagerung von Kugelwellen:
#
# <div style="text-align:center;">
#     <img src="Kugelwellen.png" width=600>
#     <p><b>Abbildung 2.5:</b> Entstehung der Beugung durch Überlagerung von Kugelwellen a) Eine Kugelwelle. b) 2 Kugelwellen etwas verschoben c) 3 Kugelwellen etwas verschoben</p>
# </div>
#
# In Abbildung 2.5 ist der Effekt der Überlagerung mehrerer Kugelwellen dargestellt: in a)
# sind die Maxima einer einzelnen Kugelwelle als konzentrische Kreise abgebildet. In b) ist
# die  Überlagerung  von  2  solchen  Kugelwellen  gezeichnet.  Immer,  wenn  zwei  Linien  sich
# exakt überdecken, entsteht konstruktive Interferenz; wo Linien „nebeneinander“ sind, ist
# die  Interferenz  partiell  destruktiv.  Man  erkennt,  dass  bereits  bei  2  Kugelwellen  die
# konstruktive Interferenz nur in bestimmte Richtungen erfolgt, symbolisch durch 3
# beispielhafte Pfeile dargestellt. In Bild c) sind drei Kugelwellen überlagert. Die Richtungen
# für konstruktive Interferenz bleiben im wesentlichen dieselben, sind aber von der
# Winkelbreite deutlich schmaler, weswegen die Pfeile auch schmaler dargestellt sind.
#
# Eine Realisation  dieser  Beugung ist die Durchstrahlung eines Strichgitters mit Licht wie
# in Abbildung 2.6 dargestellt.  Der Abstand zwischen 2 Strichen heißt **Gitterkonstante** d:
# Jede  Öffnung  ist  nun  Ausgangspunkt  neuer  Kugelwellen.  Man  zeichnet  aber  nicht  mehr
# die konzentrischen Kreise, sondern nur noch die konstruktiv interferierten Teilstrahlen.
# Zwei benachbarte Strahlen durchlaufen unterschiedliche Weglängen bis zu einem Schirm;
# dieses nennt man Gangunterschied. Der Gangunterschied ist in der Skizze mit $\delta$ bezeichnet.
# Die  Bedingung  für  konstruktive  Interferenz  ist,  dass  der  Gangunterschied
# gerade ein ganzzahliges Vielfaches der Wellenlänge beträgt, d.h., es muss gelten:
# $$
#     d \cdot \sin \beta_n = n \cdot \lambda \tag{1.9}
# $$
# Die Zahl n deutet an, dass es mehrere Richtungen konstruktiver Interferenz gibt.
#
# <div style="text-align:center;">
#     <img src="Skizze_Gangunterschied.png" width=600>
#     <p><b>Abbildung 2.6:</b> Skizze zum Gangunterschied</p>
# </div>
# Bei  bekannter  Gitterkonstante d  kann  die  Wellenlänge  einer  unbekannten  Strahlung
# bestimmt werden. Kennt man die Wellenlänge, kann die Gitterkonstante ermittelt
# werden. Das ist auch das Prinzip der Röntgenstrukturuntersuchung.

# %% [markdown]
# ## 2 Experimentelles
#
# In diesem Versuch  wird  ein  Gitter  mit  einem  Laser  bestrahlt  und  das  auf  einem  Schirm
# entstehende Beugungsmuster, welches aufgrund von Interferenzerscheinungen entsteht,
# untersucht.  Bei  dem  Gitter  handelt es  sich  um  ein  Siebgewebe  aus  Stahldraht. Bei
# Beleuchtung  mit  einem  Laserpointer  wirkt  es  als  ein  Transmissions-Amplitudengitter,
# das  heißt,  die  Amplitude  der  einfallenden  Welle  wird  durch  das  Gitter  moduliert.  Es
# handelt  sich  außerdem  um  ein  Kreuzgitter,  nicht  um  ein  Strichgitter,  das  heißt,  die
# Modulation  der  Amplitude  erfolgt  in  zwei  Dimensionen.  Daraus  ergibt  sich  auch  ein zweidimensionales Beugungsmuster. Der Versuchsaufbau ist in Abbildung 2.7
# schematisch dargestellt. Abbildung 2.8 zeigt schematisch das auf dem Schirm entstehende
# Beugungsbild.
#
#
# <div style="text-align:center;">
#     <img src="Beugung_an_Gitter.png" width=600>
#     <p><b>Abbildung 2.7:</b> Beugung eines Laserstrahls an einem Transmissionsgitter.</p>
# </div>
#
# Die Gitterkonstante d ist der Abstand zwischen den Mitten benachbarter Sieböffnungen
# (also  eine  Maschenöffnung  plus  eine  Drahtdicke), $\beta_n$  ist  der  Beugungswinkel  für  das
# Maximum der n-ten Ordnung, und $\lambda$  ist die Wellenlänge des Lasers.
#
# Für $n = 0$ ist auch der Beugungswinkel $\beta_0 = 0$.  Das Beugungsmaximum 0. Ordnung liegt
# somit  an  der  Stelle,  an  der  der  Strahl  ohne  Gitter  auf  den  Schirm  träfe.  Alle  weiteren
# Beugungsmaxima liegen bei positiven ($\beta_{n>0} > 0$) bzw. negativen ($\beta_{n<0} < 0$) Winkeln. Die
# Winkel können direkt aus den geometrischen Abmessungen des Experiments berechnet
# werden. Dieser Zusammenhang gilt sowohl in x- als auch in y-Richtung. Die Abbildung 2.8
# ist nur ein Prinzipbild des Beugungsbildes. In Wirklichkeit gibt es auch nur sehr schwach
# leuchtende Lichtpunkte, die durch bestimmte Zahlenverhältnisse Drahtdicke zu
# Öffnungsdurchmesser verursacht werden.
# Abbildung 2.8: Schematisches Beugungsbild auf dem Schirm.
#
# <div style="text-align:center;">
#     <img src="Beugungsbild.png" width=600>
#     <p><b>Abbildung 2.8:</b> Schematische Beugungsbild auf einem Schirm</p>
# </div>
#
# Im rechtwinkligen Dreieck in Abbildung 2.9 sind $z_0$ und $y_n$ die Katheten. Daraus ergibt sich für die Winkel in Abbildung 2.7 der folgende Ausdruck:
# $$
#     \beta_n = \arctan (\frac{y_n}{z_0}) \tag{2.1}
# $$
#
# <div style="text-align:center;">
#     <img src="Bestimmung_Beugungswinkel.png" width=600>
#     <p><b>Abbildung 2.9:</b> Bestimmung des Beugungswinkels.</p>
# </div>
#
# Im Versuch soll zunächst die Wellenlänge des Lasers $\lambda$ durch Beugung an einem Gitter mit
# bekannter Gitterkonstante d ermittelt werden. Anschließend kann über die nun bekannte
# Wellenlänge die Gitterkonstante eines unbekannten Gitters gemessen werden.

# %% [markdown]
# ## 3 Versuchsdurchführung
#
# ### 3.1 Versuchsaufbau
#
# Zum  Versuchsaufbau  gehören  zwei  Laserpointer  mit  unterschiedlichen  Wellenlängen,
# zwei  Siebgitter  (eines  mit  bekannter  und  eines  mit  unbekannter  Gitterkonstante),  eine
# Papierhalterung  für  mm-Papier sowie eine digitale Industriekamera (monochrom). Alle
# Komponenten  können  mit  Haltern auf  eine  optische  Schiene  geschoben  und  fixiert
# werden;  alle  Verschiebungen  der  Elemente  müssen  vorsichtig  vorgenommen  werden..
# Die Kamera wird mit  einem PC gesteuert. Die gesamte Auswertung wird auf demselben
# PC durchgeführt.
#
# Montieren Sie das Sieb und den Laser auf die Schiene. Für die Bildaufnahme müssen Sie
# geeignete Abstände wählen (großes z0 ermöglicht eine genauere Winkelmessung,
# allerdings kann man dann nur weniger Reflexe auf die Mattscheibe bringen und
# umgekehrt). Messen Sie den Abstand z0.
#
# <div style="text-align:center;">
#     <img src="Aufbau.png" width=600>
#     <p><b>Abbildung 2.10:</b> Aufbau</p>
# </div>
#
# ### 3.2 Durchführung
#
# Das  zu beobachtende  Beugungsmuster  kann  durch Verschieben  einzelner  Elemente
# optimiert werden. Es wird mit der Industriekamera fotografiert und auf dem PC
# abgespeichert;  die  Bediensoftware  der  Kamera  heißt  „GalaxyView“.  Das  abgespeicherte
# Bild wird mit der Software „ImageJ“ graphisch ausgewertet. Die notwendigen
# Berechnungen werden mit der Software „OriginPro“ an den Praktikumscomputern
# vorgenommen.

# %% [markdown]
# ## Auswertung der Fotos mit ImageJ
#
# ### Aufgaben
#
# Folgende Aufgaben sollen gemacht werden:
#
# 1. Berechnung der Laserwellenlänge des ersten Laserpointers aus dem Mittelwert
# 2. Berechung der Laserwellenlänge des ersten Laserpointers einer Auftragung
# 3. Berechnung der Gitterkonstante des unbekannten Gitters aus den Messwerten.
# 4. Bestimmung aus einer Auftragung;Vergleich der unterschiedlichen Beugungsmuster in Abhänigkeit der Laserwellenlänge(qualitativ)
#
# Vergleichen sie jeweils die Ergebnisse 1/2 und 3/4. Welches ist genauer?
#
# Die Abstände der  einzelnen Reflexe zu  dem Punkt nullter  Ordnung werden mithilfe der
# Software  „ImageJ“  bestimmt.  Dazu  müssen  Sie  zuerst  eine  Referenzlinie  in  das  Foto
# einzeichnen: Sie zeichnen bei aktiviertem Linienwerkzeug mit dem Mauszeiger eine Linie
# auf  dem  mm-Papier  nach.  In  der  entsprechenden  Dialogbox  „Set  Scale  ...“  geben  Sie  die
# reale  Länge  ein  (z.B.  30  mm).  Anschließend  zeichnen  Sie  eine  Linie  entlang  mehrerer
# Beugungsreflexe.  Das  Intensitätsprofil  dieser  Linie  kann  in  einem  separaten  Fenster
# angezeigt  werden.  In  diesem  Fenster  suchen  Sie  durch  einfaches  Klicken  mithilfe  des
# „Multipoint-Tools“ die Orte der Beugungsreflexe aus (immer die Mitte einer
# Reflexverteilung). Den Punkt nullter Ordnung markieren Sie am besten mit dem höchsten
# y-Wert,  damit  er  in  der  entstehenden  Punktliste  sofort  erkennbar  ist.  Nachdem  alle
# Punkte ausgewählt wurden, können Sie mit der Tastenkombination Strg+M die Liste der
# ausgewählten Punkte anzeigen. Mithilfe von Strg-A werden alle Punkte markiert und mit
# Strg+C  in  die  Zwischenablage  des PCs  kopiert.  Anschließend können  Sie  zu Origin
# wechseln  und  die  Daten  dort  mit  Strg+V  in  ein  Worksheet  hineinkopieren.  Dort  findet
# dann die grafische Darstellung sowie die rechnerische Auswertung statt
#
# ### Bekanntes Gitter / unbekannter Laser: Auswertung der Wellenlänge nach einzelnen Reflexen und Mittelwertbildung
#
# Aus den so ermittelten Parametern $z_0$ und $y_n$ werden mithilfe der Gleichungen die Winkel $\beta_{-n}$ und $\beta_n$ für die berechnet. Einsetzen in die Gleichung erlaubt die Berechnung der Wellenlänge für jeden der Streuwinkel. Der Mittelwert dieser sechs Werte ergibt die mittlere Laserwellenlänge $\lambda_{mittel}$
#
# ### Bekanntes Gitter / unbekannter Laser: Auswertung der Wellenlänge nach einzelnen Reflexen gleichzeitig aus einer Auftragung
#
# Anschließend wird die Laserwellenlänge durch eine Auftragung derselben Daten
# bestimmt. Gleichung (2.10) lässt sich zu
# $$
#     \sin \beta_n = \frac{n}{d} \cdot \lambda \tag{3.1}
# $$
# umstellen. Aus der Auftragung von $\sin \beta_n$ vs. n/d erhält man die Laserwellenlänge $\lambda$ als Steigung.
#
# ### Unbekanntes Gitter / bekannter Laser: Auswertung der Gitterkonstante nach einzelnen Reflexen und Mittelwertbildung
#
# Die  Gitterkonstante d  eines  unbekannten  Gitters  lässt  sich  berechnen,  indem  Gleichung
# (2.10) nach d aufgelöst wird:
# $$
#     d = \frac{n \cdot \lambda}{\sin \beta_n} \tag{3.2}
# $$
#
# Aus den Werten für d lässt sich ein Mittelwert $d_{mittel}$ berechnen
#
# ### Unbekanntes Gitter / bekannter Laser: Auswertung der Gitterkonstante durch alle Reflexe gleichzeitig
#
# Auch d lässt sich aus einer Auftragung ermitteln. Dazu wird $n \cdot \lambda$ vs. $\sin \beta_n$ aufgetragen, woraus man d aus der Steigung erhält.

# %% [markdown]
# ## 4 Messergebnisse
#
# ### 4.1 Messung z0
#
# Der Abstand zwischen Laser und gitter $z_0$ wurde gemessen als:

# %%
z0 = 0.6918
z0_std = 0.005

yn_std = 0.005

print("Mittelwert ....... z0 = %.4f m" % z0)
print("Standartabweichung z0 = %.4f m" % z0_std)
# Out:
# Mittelwert ....... z0 = 0.6918 m
# Standartabweichung z0 = 0.0050 m

# %% [markdown]
# ### 4.2 Messergebnisse unbekannte Wellenlänge
#
# Für die Durchführung mit unbekannter Wellenlänge des Lasers wurde die Gitterkonstante gegeben als
# $$
#     d = 5 \cdot 10^{-5} m \tag{4.1}
# $$
# Hierbei wurden die Abstände der Ordnungen $y_n$ gemessen als

# %%
d = 5 * pow(10, -5)

yn_lmbda_data = StringIO("""
    #Ordnung yn/m
    -5       -0.036167
    -3       -0.021818
    -2       -0.014350
    -1       -0.006881
    0        0   
    1        0.007468   
    2        0.015104   
    3        0.022405
    5        0.036503
""")

n_lmbda, yn_lmbda = np.loadtxt(yn_lmbda_data, unpack=True)

# %%
#Ist der Plot genug aussagend wenn man das experiment versteht ja aber sonst könnte verwirrung stiften

plt.figure(figsize=(figwidth,  0.5*figwidth))
plt.plot(n_lmbda , yn_lmbda *10**3, '-o')
plt.xlabel("Ordnung")
plt.ylabel(r'$y_n$ / mm')
plt.grid()
plt.yticks(yn_lmbda * 10**3)
plt.xticks(n_lmbda)

plt.title("Bei unbekannter Wellenlänge gemessene yn gegen die Ordnung aufgertragen")
plt.show()

# %% [markdown]
# ### 4.3 Messergebnisse unbekannte Gitterkonstante
#
# Für die Durchführung des Experiments mit unbekannter Gitterkonstante wurde ein Laser benutzt mit bekannter Wellenlänge
# $$
#     \lambda = 5.32 \cdot 10^{-7} m \tag{4.2}
# $$
# Dabei wurden erneut die Abstände $y_n$ gemessen, für die sich folgende Werte ergaben

# %%
lmbda = 5.32 * pow(10, -7)

yn_d_data = StringIO("""
#Ordnung yn / m
-4       -0.016921
-3       -0.012855
-2       -0.008523   
-1       -0.004527   
0         0
1         0.004108  
2         0.008384  
3         0.012296  
4         0.016572  
5         0.020680  
""")

n_d, yn_d = np.loadtxt(yn_d_data, unpack=True)

# %%
#Ist der Plot genug aussagend wenn man das experiment versteht ja aber sonst könnte verwirrung stiften

plt.figure(figsize=(figwidth,  0.5*figwidth))
plt.plot(n_d, yn_d* 10**3, '-o')
plt.xlabel("Ordnung")
plt.ylabel(r'$y_n$ / mm')
plt.grid()
plt.yticks(yn_d * 10**3)
plt.xticks(n_d)

plt.title("Bei unbekannter Gitterkonstante gemessene yn gegen die Ordnung aufgertragen")
plt.show()

# %%
#Entferne Null werte da in folgenden Berechnungen immer null sind:
#Unbekannte Wellenlänge:
n_lmbda = n_lmbda[n_lmbda!=0]
yn_lmbda = yn_lmbda[yn_lmbda!=0]

#Unbekannte Gitterkonstante
n_d = n_d[n_d!=0]
yn_d = yn_d[yn_d!=0]

# %% [markdown]
# ## 5 Auswertung
#
# ### 5.1 Bestimmung der Wellenlänge
#
# #### 5.1.1 Rechnerische Bestimmung
#
# Durch einsetzen von $z_0$ und den entsprechenden $y_n$ in Formel (2.1) ergeben sich die entsprechenden Beugungswinkel $\beta_n$

# %%
beta_lmbda = np.arctan((yn_lmbda/z0))


plt.subplots()
plt.axis("off")

plt.table(
    cellText=list(zip(n_lmbda, beta_lmbda)),
    colLabels=["n", r"$\beta_n$"],
    loc="center"
)
plt.title(r"Berechnete Werte von $\beta_n$")

plt.show()

# %%
sinBeta_lmbda = np.sin(beta_lmbda)

plt.subplots()
plt.axis("off")

plt.table(
    cellText = list(zip(n_lmbda, sinBeta_lmbda)),
    colLabels=["n", r"$\sin \beta_n$"],
    loc="center"
)
plt.title(r"Berechnete Werte von $\sin\beta_n$")
plt.show()

# %% [markdown]
# Durch umstellen der Formel (3.1) ergibt sich folgende Formel zur Berechnung von $\lambda$
#
# $$
#     \lambda = \frac{d \cdot \sin \beta_n}{n} \tag{5.1}
# $$
#
# Nun kann man die entsprechenden Werte in die Formel einsetzen und erhält folgende Werte als $\lambda$

# %%
lmbda_lmbda = d * sinBeta_lmbda / n_lmbda 


plt.subplots()
plt.axis("off")

plt.table(
    cellText = list(zip(n_lmbda, lmbda_lmbda)),
    colLabels=["n", r"$\lambda$ / m"],
    loc="center"
)
plt.title("Berechnete Werte der Wellenlänge")
plt.show()

# %%
lmbda_lmbda_mean = np.mean(lmbda_lmbda)
lmbda_lmbda_std = np.std(lmbda_lmbda)

#f strings zu kompliziert? Also könnte auch mit log machen?
print(f"Mittelwert ............ lambda = {lmbda_lmbda_mean:.3e} m")
print(f"Unsicherheit Mittelwert lambda = {lmbda_lmbda_std:.3e} m")
# Out:
# Mittelwert ............ lambda = 5.269e-07 m
# Unsicherheit Mittelwert lambda = 1.436e-08 m

# %%
plt.figure(figsize=(figwidth, 0.7*figwidth))

plt.subplot(3,1,1)
plt.plot(n_lmbda, beta_lmbda, '-o')
plt.xlabel("Ordnung")
plt.ylabel(r"$\beta_n$")
plt.xticks(n_lmbda)

plt.subplot(3,1,2)
plt.plot(n_lmbda, sinBeta_lmbda, '-o')
plt.xlabel("Ordnung")
plt.ylabel(r"$\sin \beta_n$")
plt.xticks(n_lmbda)

plt.subplot(3,1,3)
plt.plot(n_lmbda, lmbda_lmbda, '-o', label="Werte")
plt.axhline(lmbda_lmbda_mean, color="C1", label = "Mittelwert")
plt.xlabel("Ordnung")
plt.ylabel(r"$\lambda$ / m")
plt.xticks(n_lmbda)
plt.legend(loc="lower right")

plt.suptitle("Visualisierungen Rechnungen")
plt.tight_layout()
plt.show()

# %%
#~~~~~~~~~~~~~~~~
#Fehlerrechnung
#~~~~~~~~~~~~~~~~

#Wo grafisch ausgeben? Oder allgemein grafisch ausgeben?

delta_betan_lmbda = np.sqrt((-yn_lmbda*yn_std/(z0**2 + yn_lmbda**2))**2 + (z0*z0_std/(yn_lmbda**2 + z0**2))**2)

delta_sinBetan_lmbda = np.sqrt((np.cos(beta_lmbda) * delta_betan_lmbda)**2)

# %% [markdown]
# #### 5.1.2 Bestimmung durch Auftragung
#
# Die Wellenlänge kann auch durch Auftragung durch alle Reflexe gleichzeitig bestimmt werden. Dafür wird nach Formel (3.1) $\sin \beta_n$ gegen $\frac{n}{d}$ aufgetragen. Als y Fehler wird $\Delta \sin \beta_n$ benutzt. Die Steigung ergibt die Wellenlänge.

# %%
xData_lmbda = n_lmbda/d

#Können die das verstehen? Also polyfit an sich ok aber fehler und was wenn es x fehler gibt was dann? Oder gibt es was besseres?
p,cov = np.polyfit(xData_lmbda, sinBeta_lmbda, 1, w=1/delta_sinBetan_lmbda, cov=True)
lmbda_graph,b = p
delta_lmbda_graf = np.sqrt(cov[0,0])

print(f"Auftragung ............ lambda = {lmbda_graph:.3e} m")
print(f"Unsicherheit Auftragung lambda = {delta_lmbda_graf:.3e} m")

plt.plot(xData_lmbda, lmbda_graph*xData_lmbda+b, linestyle="--", label=f"Fit: y = {lmbda_graph:.4f}x + {b:.4f}", linewidth=2)
plt.errorbar(xData_lmbda, sinBeta_lmbda, yerr=delta_sinBetan_lmbda, fmt="o", markersize=3, capsize=5, capthick=1.5 , elinewidth= 1.5, color="black", ecolor="black")
plt.xlabel(r"$\frac{n}{d}$ / $m^{-1}$")
plt.ylabel(r"$\sin \beta_n$")
plt.title("Auftragung Wellenlänge")
plt.grid(True)
plt.show()
# Out:
# Auftragung ............ lambda = 5.269e-07 m
# Unsicherheit Auftragung lambda = 1.745e-09 m

# %% [markdown]
# ### 5.2 Bestimmung der Gitterkonstante
#
# #### 5.2.1 Rechnerische Bestimmung
#
# Auch für die durchführung mit unbekannter Gitterkonstante kann selbe rechnerisch bestimmt werden. Dabei wird zunächst analog mit dem bestimmen des Beugungswinkels $\beta_n$ angefangen. Dies wird ebenfalls mit Formel (2.1) gemacht. Danach wird ebenfalls der sinus genommen. Es ergibt sich

# %%
beta_d = np.arctan(yn_d/z0)


plt.subplots()
plt.axis("off")

plt.table(
    cellText=list(zip(n_d, beta_d)),
    colLabels=["n", r"$\beta_n$"],
    loc="center"
)
plt.title(r"Berechnnete Werte $\beta_n$")

plt.show()

# %%
sin_beta_d = np.sin(beta_d)


plt.subplots()
plt.axis("off")

plt.table(
    cellText=list(zip(n_d, sin_beta_d)),
    colLabels=["n", r"$\sin \beta_n$"],
    loc="center"
)
plt.title(r"Berechnete Werte $\sin\beta_n$")

plt.show()

# %% [markdown]
# Nun kann direkt mit Formel (3.2) die Gitterkonstante berechnet werden.

# %%
d_d = n_d * lmbda / sin_beta_d


plt.subplots()
plt.axis("off")

plt.table(
    cellText=list(zip(n_d, d_d)),
    colLabels=["n", r"d / m"],
    loc="center"
)
plt.title("Berechnete Werte der Gitterkonstante")

plt.show()

# %%
d_d_mean = np.mean(d_d)
d_d_std = np.std(d_d)

#f strings ok?
print(f"Mittelwert ............ Gitterkonstante = {d_d_mean:.3e} m")
print(f"Unsicherheit Mittelwert Gitterkonstante = {d_d_std:.3e} m")
# Out:
# Mittelwert ............ Gitterkonstante = 8.730e-05 m
# Unsicherheit Mittelwert Gitterkonstante = 2.496e-06 m

# %%
plt.figure(figsize=(figwidth, 0.7*figwidth))

plt.subplot(3,1,1)
plt.plot(n_d, beta_d, '-o')
plt.xlabel("Ordnung")
plt.ylabel(r"$\beta_n$")
plt.xticks(n_d)

plt.subplot(3,1,2)
plt.plot(n_d, sin_beta_d, '-o')
plt.xlabel("Ordnung")
plt.ylabel(r"$\sin \beta_n$")
plt.xticks(n_d)

plt.subplot(3,1,3)
plt.plot(n_d, d_d, '-o', label="Werte")
plt.axhline(d_d_mean, color="C1", label = "Mittelwert")
plt.xlabel("Ordnung")
plt.ylabel(r"d / m")
plt.xticks(n_d)
plt.legend(loc="lower right")

plt.suptitle("Visualisierungen Rechnungen")
plt.tight_layout()
plt.show()

# %%
#~~~~~~~~~~~~~~
#Fehlerrechnung
#~~~~~~~~~~~~~~

#Wo darstellen?

delta_betan_d= np.sqrt((-yn_d*yn_std/(z0**2 + yn_d**2))**2 + (z0*z0_std/(yn_d**2 + z0**2))**2)

delta_sinBetan_d= np.sqrt((np.cos(beta_d) * delta_betan_d)**2)

# %% [markdown]
# #### 5.2.2 Bestimmung durch Auftragung
#
# Ebenfalls kann die Gitterkonstante durch Auftragung bestimmt werden. Dafür wird $n \cdot \lambda$ gegen $\sin \beta_n$ Aufgetragen. Dabei ist $\Delta \sin \beta_n$ der x Fehler

# %%
nlambda_d = n_d * lmbda


d_graph,b= np.polyfit(sin_beta_d, nlambda_d, 1)

print(f"Auftragung ............ Gitterkonstante = {d_graph:.3e} m")
#Placeholder bis ich weiß wie man mit x fehler berechnet
print(f"Unsicherheit Auftragung Gitterkonstante = {delta_lmbda_graf:.3e} m")

plt.plot(sin_beta_d, d_graph*sin_beta_d+b, linestyle="--", linewidth=2)
plt.errorbar(sin_beta_d, nlambda_d, xerr=delta_sinBetan_d, fmt="o", markersize=3, capsize=5, capthick=1.5 , elinewidth= 1.5, color="black", ecolor="black")
plt.xlabel(r"$\sin \beta_n$")
plt.ylabel(r"$n \cdot \lambda$ / m")
plt.title("Auftragung Gitterkonstante")
plt.grid(True)
plt.show()
# Out:
# Auftragung ............ Gitterkonstante = 8.783e-05 m
# Unsicherheit Auftragung Gitterkonstante = 1.745e-09 m

# %% [markdown]
# ## 6 Fehlerrechnung
#
# ### 6.1 Standart Abweichung des Mittelwerts
#
# Die Standartabweichung eines Mittelwerst kann mit folgender Formel berechnet werden.
#
# $$
#     \bar{S_N} = \sqrt{\frac{1}{N-1} \cdot \sum_{i=1}^{N} (x_i - x_{mittel})²} \tag{6.1}
# $$
#
# Damit kann die Standartabweichung des berechneten Mittelwerts der Wellenlänge und der Gitterkonstante berechnet werden
#
# $$
#     \begin{align*}
#         \Delta\lambda_{berechnet} &= 1,436 \cdot 10^{-8} m\\ \tag{6.2}
#         \Delta d_{berechnet} &= 2,496 \cdot 10^{-6} m
#     \end{align*}
# $$
#
# ### 6.2 Abschätzung $\Delta z_0$ und $\Delta y_n$
#
# $z_0$ und $y_n$ sind gemessene Werte, deshalb muss als Messunsicherheit die Hälfte der Messskala verwendet werden. Da $z_0$ mit einem Geodreieck und $y_n$ mit einem Zollstock gemessen wurde und beide auf 1 mm genau skaliert sind, muss der Fehler angenommen werden als
# $$
#     \begin{align*}
#         \Delta z_0 &= 0,005 m\\ \tag{6.3}
#         \Delta y_n &= 0,005 m
#     \end{align*}
# $$
#
# ### 6.3 Fehlerfortpflanzung zur Berechnung von $\Delta\beta_n$ und $\Delta\sin\beta_n$
#
# Für die Fehlerrechnung wird die Gaußsche Fehlerfortpflanzung benutzt ist, welche wie folgt definiert ist
# $$
#     \Delta f = \sqrt{\sum_i (\frac{\partial f}{\partial x_i} \cdot \Delta x_i )²} \tag{6.4}
# $$
#
# Das eingesetzt und differenziert für Formel (2.1) ergibt sich die Formel für $\Delta\beta_n$
#
# $$
#     \Delta\beta_n = \sqrt{(-\frac{y_n \cdot \Delta y_n}{z_0^2 + y_n^2})² + (\frac{z_0 \cdot \Delta z_0}{z_0^2 + y_n^2})²} \tag{6.5}
# $$
#
# Es ergeben sich folgende Werte für den Fehler des Beugungswinkels:

# %%
plt.figure(figsize=(12, 0.5*figwidth))

plt.subplot(1,2,1)
plt.axis("off")
plt.table(
    cellText=list(zip(n_lmbda, delta_betan_lmbda)),
    colLabels=["n", r"$\Delta\beta_n$"],
    loc="center"
)
plt.title(r"$\Delta\beta_n$ Werte für unbekannte Wellenlänge")

plt.subplot(1,2,2)
plt.axis("off")
plt.table(
    cellText=list(zip(n_d, delta_betan_d)),
    colLabels=["n", r"$\Delta\beta_n$"],
    loc="center"
)
plt.title(r"$\Delta\beta_n$ Werte für unbekannte Gitterkonstante")


plt.show()

# %% [markdown]
# Das gleiche wird noch wird dann noch für $\Delta\sin\beta_n$ gemacht. Es ergibt sich
# $$
#     \Delta\sin\beta_n = \sqrt{(\cos\beta_n \cdot \Delta\beta_n)²} \tag{6.6}
# $$
#
# Es ergeben sich die Werte

# %%
plt.figure(figsize=(12, 0.5*figwidth))

plt.subplot(1,2,1)
plt.axis("off")
plt.table(
    cellText=list(zip(n_lmbda, delta_sinBetan_lmbda)),
    colLabels=["n", r"$\Delta\sin\beta_n$"],
    loc="center"
)
plt.title(r"$\Delta\sin\beta_n$ Werte für unbekannte Wellenlänge")

plt.subplot(1,2,2)
plt.axis("off")
plt.table(
    cellText=list(zip(n_d, delta_sinBetan_d)),
    colLabels=["n", r"$\Delta\sin\beta_n$"],
    loc="center"
)
plt.title(r"$\Delta\sin\beta_n$ Werte für unbekannte Gitterkonstante")


plt.show()

# %% [markdown]
# ### 6.4 Fehlerabschäzung der Grafisch bestimmten werte
#
# Zur bestimmung des Grapischen fehlers wird bei unbekannter Wellenlänge $\Delta\sin\beta_n$ als y-Fehler benutzt. Da $\frac{n}{d}$ einerseits eine Ordnung und das andere ein gegebener Wert ist, der als mfehlerfrei angenommen werden kann braucht es keinen x Fehler.
# Beim bestimmen der Gitterkonstante wird dieses mal $\Delta\sin\beta_n$ als x-Fehler angenommen und es gibt keinen y-Fehler, da erneut $\lambda$ ein gegebener als fehlerlos angenommener Wert ist und n die Ordnung ist.
# Es ergeben sich folgende Werte als Unsicherheiten der mit Auftragung bestimmten Werten
#
# $$
#     \begin{align*}
#         \lambda_{grafisch} &= 1,745 \cdot 10^{-9} m\\ \tag{6.7}
#         d_{grafisch} &= 1,745 \cdot 10^{-9} m
#     \end{align*}
# $$

# %% [markdown]
# ## 7 Diskussion
#
# ### 7.1 Zusammenfassung der Ergebnisse
#
# $$
#     \begin{align*}
#         \lambda_{berechnet} &= 5,269 \cdot 10^{-7} \pm 1,436 \cdot 10^{-9} m\\ \tag{7.1}
#         \lambda_{grafisch} &= 5,269 \cdot 10^{-7} \pm 1,745 \cdot 10^{-9} m\\
#         d_{berechnet} &= 8,730 \cdot 10^{-5} \pm 2,496 \cdot 10^{-6} m\\
#         d_{grafisch} &= 8,783 \cdot 10^{-5} \pm 1,745 \cdot 10^{-9} m
#     \end{align*}
# $$

# %% [markdown]
# ### 7.2 Diskusion der Werte/Fehler
#
# Diskussion lass ich mal weg ist denke nur Zeitverschwendung
